# %%
There is two way acessing the from internet/web:
    1.http[usually used]
    2.API[Application Programming Interface]

# %% [markdown]
# # 1. Http

# %% [raw]
# 1.usually for reciving data from web/internet we use http[hyper text transport protocal] there we got the Data in HTML and CSS form[web page]

# %% [markdown]
# # 2. API

# %% [raw]
# API is the pipline between two software.
# In simplest form API is the simplest function which we put on the server which has some url, after hitting on that url and passing the correct parametes,Its give us some response/result in JSON[[javascript object notation] format.

# %%
Create the account on API

# %%
# now for practice purpose i will created the account on [TMDB API]

# %%
By the way short note on API

# %% [raw]
# Now a current Scenario/econamy prespective, API are very important.
# Ex.,
# when we can book the train tickit by IRCT, makemytrip,exigo,goibo.....
# ok,once the particular tickit is booked from the IRCT, can that tickit also show booked on makemytrip,goibo... the answer is yes and you cant do transaction on it.
# Now think about it ,the DATABASE is of IRTC but every company know which seat is booked or not Because they are communicating with IRCT DATABASE by their API.

# %%
import requests
import pandas as pd

# %%
response=requests.get('https://api.themoviedb.org/3/movie/popular?api_key=290c56582df36f9e41f90ba8edf56fad&language=en-US&page=1').json()

# %%
d1={}
df=[d1[j].append(i[j])for i in response['results'] for j in i.keys()]
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [31], in <cell line: 2>()
#       1 d1={}
# ----> 2 df=[d1[j].append(i[j])for i in response['results'] for j in i.keys()]
#       3 df
#
# Input In [31], in <listcomp>(.0)
#       1 d1={}
# ----> 2 df=[d1[j].append(i[j])for i in response['results'] for j in i.keys()]
#       3 df
#
# KeyError: 'adult'

# %%
df={}
for i in response['results']:
    for j in i.keys():
        print(j)
        df[j]=[].append(i[j])
df
# Out:
# adult
# backdrop_path
# genre_ids
# id
# original_language
# original_title
# overview
# popularity
# poster_path
# release_date
# title
# video
# vote_average
# vote_count
# adult
# backdrop_path
# genre_ids
# id
# original_language
# original_title
# overview
# popularity
# poster_path
# release_date
# title
# video
# vote_average
# vote_count
# adult
# backdrop_path
# genre_ids
# id
# original_language
# original_title
# overview
# popularity
# poster_path
# release_date
# title
# video
# vote_average
# vote_count
# adult
# backdrop_path
# genre_ids
# id
# original_language
# original_title
# overview
# popularity
# poster_path
# release_date
# title
# video
# vote_average
# vote_count
# adult
# backdrop_path
# genre_ids
# id
# original_language
# original_title
# overview
# popularity
# poster_path
# release_date
# title
# video
# vote_average
# vote_count
# adult
# backdrop_path
# genre_ids
# id
# original_language
# original_title
# overview
# popularity
# poster_path
# release_date
# title
# video
# vote_average
# vote_count
# adult
# backdrop_path
# genre_ids
# id
# original_language
# original_title
# overview
# popularity
# poster_path
# release_date
# title
# video
# vote_average
# vote_count
# adult
# backdrop_path
# genre_ids
# id
# original_language
# original_title
# overview
# popularity
# poster_path
# release_date
# title
# video
# vote_average
# vote_count
# adult
# backdrop_path
# genre_ids
# id
# original_language
# original_title
# overview
# popularity
# poster_path
# release_date
# title
# video
# vote_average
# vote_count
# adult
# backdrop_path
# genre_ids
# id
# original_language
# original_title
# overview
# popularity
# poster_path
# release_date
# title
# video
# vote_average
# vote_count
# adult
# backdrop_path
# genre_ids
# id
# original_language
# original_title
# overview
# popularity
# poster_path
# release_date
# title
# video
# vote_average
# vote_count
# adult
# backdrop_path
# genre_ids
# id
# original_language
# original_title
# overview
# popularity
# poster_path
# release_date
# title
# video
# vote_average
# vote_count
# adult
# backdrop_path
# genre_ids
# id
# original_language
# original_title
# overview
# popularity
# poster_path
# release_date
# title
# video
# vote_average
# vote_count
# adult
# backdrop_path
# genre_ids
# id
# original_language
# original_title
# overview
# popularity
# poster_path
# release_date
# title
# video
# vote_average
# vote_count
# adult
# backdrop_path
# genre_ids
# id
# original_language
# original_title
# overview
# popularity
# poster_path
# release_date
# title
# video
# vote_average
# vote_count
# adult
# backdrop_path
# genre_ids
# id
# original_language
# original_title
# overview
# popularity
# poster_path
# release_date
# title
# video
# vote_average
# vote_count
# adult
# backdrop_path
# genre_ids
# id
# original_language
# original_title
# overview
# popularity
# poster_path
# release_date
# title
# video
# vote_average
# vote_count
# adult
# backdrop_path
# genre_ids
# id
# original_language
# original_title
# overview
# popularity
# poster_path
# release_date
# title
# video
# vote_average
# vote_count
# adult
# backdrop_path
# genre_ids
# id
# original_language
# original_title
# overview
# popularity
# poster_path
# release_date
# title
# video
# vote_average
# vote_count
# adult
# backdrop_path
# genre_ids
# id
# original_language
# original_title
# overview
# popularity
# poster_path
# release_date
# title
# video
# vote_average
# vote_count
# {'adult': None,
#  'backdrop_path': None,
#  'genre_ids': None,
#  'id': None,
#  'original_language': None,
#  'original_title': None,
#  'overview': None,
#  'popularity': None,
#  'poster_path': None,
#  'release_date': None,
#  'title': None,
#  'video': None,
#  'vote_average': None,
#  'vote_count': None}
