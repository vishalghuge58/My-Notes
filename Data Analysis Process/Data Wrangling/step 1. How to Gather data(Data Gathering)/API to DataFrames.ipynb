# %% [raw]
# There is two way acessing data from internet/web:
#     1.http[usually used]
#     2.API[Application Programming Interface]

# %% [markdown]
# # 1. Http

# %% [raw]
# 1.usually for reciving data from web/internet we use http[hyper text transport protocal] there we got the Data in HTML and CSS form[web page]

# %% [markdown]
# # 2. API

# %% [raw]
# API is the pipline between two software.
# In simplest form API is the simplest function which we put on the server which has some url, after hitting on that url and passing the correct parametes,Its give us some response/result in JSON[[javascript object notation] format.

# %% [raw]
# Create the account on API

# %%
# now for practice purpose i will created the account on [TMDB API]

# %% [raw]
# By the way short note on API

# %% [raw]
# Now a current Scenario/econamy prespective, API are very important.
# Ex.,
# when we can book the train tickit by IRCT, makemytrip,exigo,goibo.....
# ok,once the particular tickit is booked from the IRCT, can that tickit also show booked on makemytrip,goibo... the answer is yes and you cant do transaction on it.
# Now think about it ,the DATABASE is of IRTC but every company know which seat is booked or not Because they are communicating with IRCT DATABASE by their API.

# %%
import requests
import pandas as pd
import numpy as np

# %%
response=requests.get('https://api.themoviedb.org/3/movie/popular?api_key=290c56582df36f9e41f90ba8edf56fad&language=en-US&page=1').json()

# %%
popularity=[]
vote_count=[]
original_language=[]
vote_average=[]
overview=[]
release_date=[]

for i in response['results']:
    
    popularity.append(i['popularity'])
    vote_count.append(i['vote_count'])
    original_language.append(i['original_language'])
    vote_average.append(i['vote_average'])
    overview.append(i['overview'])
    release_date.append(i['release_date'])
    
d={'popularity':popularity,'vote_count':vote_count,'original_language':original_language,'vote_average':vote_average,'overview':overview,'release_date':release_date}    
df=pd.DataFrame(d)
df
# Out:
#     popularity  vote_count original_language  vote_average  \
# 0     7631.138         574                en           7.4
# 1     6529.681         298                en           7.1
# 2     5010.923         431                en           6.8
# 3     4548.226         331                te           7.9
# 4     3612.381        1581                ja           8.0
# 5     3474.459        3276                en           6.8
# 6     3348.480         962                en           7.0
# 7     2746.083          49                en           7.3
# 8     2586.824          88                ja           7.0
# 9     2353.634        3816                en           8.0
# 10    1983.136          67                ko           6.9
# 11    1902.250         522                en           7.6
# 12    1749.604        3322                en           7.1
# 13    1717.452        3695                en           8.4
# 14    1571.505         274                ja           7.7
# ...

# %%
final=pd.DataFrame()
popularity=[]
vote_count=[]
original_language=[]
vote_average=[]
overview=[]
release_date=[]

for j in range(1,500):
    response=requests.get('https://api.themoviedb.org/3/movie/popular?api_key=290c56582df36f9e41f90ba8edf56fad&language=en-US&page={}'.format(j)).json()
    popularity=[]
    vote_count=[]
    original_language=[]
    vote_average=[]
    overview=[]
    release_date=[]
    for i in response['results']:
        try:

            popularity.append(i['popularity'])
        except:
            popularity.append(np.nan)
        try:
            
            vote_count.append(i['vote_count'])
        except:
             vote_count.append(np.nan)
        try:
            
            original_language.append(i['original_language'])
        except:
            
            
            original_language.append(np.nan)
        try:
            
            vote_average.append(i['vote_average'])
        except:
            vote_average.append(np.nan)
        try:
            
            overview.append(i['overview'])
        except:
            overview.append(np.nan)
        try:
            
            release_date.append(i['release_date'])
        except:
            release_date.append(np.nan)

    d={'popularity':popularity,'vote_count':vote_count,'original_language':original_language,'vote_average':vote_average,'overview':overview,'release_date':release_date}    
    df=pd.DataFrame(d)
    
    final=final.append(df,ignore_index=True)

final
# Out:
# C:\Users\Vishal Ghuge\AppData\Local\Temp\ipykernel_31012\810097167.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df,ignore_index=True)
#       popularity  vote_count original_language  vote_average  \
# 0       7631.138         574                en           7.4
# 1       6529.681         298                en           7.1
# 2       5010.923         431                en           6.8
# 3       4548.226         331                te           7.9
# 4       3612.381        1581                ja           8.0
# ...          ...         ...               ...           ...
# 9975      11.166         357                es           6.7
# 9976      11.162           3                en           3.3
# 9977      11.162         482                en           6.6
# 9978      11.161          87                ru           7.2
# ...
